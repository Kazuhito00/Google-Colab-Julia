# %% [markdown]
# # 参考：[Google ColabでJuliaを使う](https://qiita.com/cometscome_phys/items/1ba6ec181bb0fe1b35d5)

# %% [markdown]
# # 事前準備
# 必要に応じてipynb自体の以下の箇所を編集する<br>
# "metadata": {<br>
# &nbsp;&nbsp;&nbsp;&nbsp;"kernelspec": {<br>
# &nbsp;&nbsp;&nbsp;&nbsp;"display_name": "Julia 1.4.2",<br>
# &nbsp;&nbsp;&nbsp;&nbsp;"language": "julia",<br>
# &nbsp;&nbsp;&nbsp;&nbsp;"name": "julia-1.4"<br>
# },
# <br>
# ※後述の「ランタイムのタイプの変更」で「Julia」以外の言語(Python等)を選択してしまうと<br>
# metadataが選択した言語に書き換わってしまうため注意

# %% [markdown]
# # ダウンロード

# %%
# !curl -sSL 'https://julialang-s3.julialang.org/bin/linux/x64/1.0/julia-1.0.5-linux-x86_64.tar.gz' -o julia.tar.gz  # LTS (Sep 9, 2019)
# !curl -sSL 'https://julialang-s3.julialang.org/bin/linux/x64/1.1/julia-1.1.0-linux-x86_64.tar.gz' -o julia.tar.gz
!curl -sSL 'https://julialang-s3.julialang.org/bin/linux/x64/1.4/julia-1.4.2-linux-x86_64.tar.gz' -o julia.tar.gz
# !curl -sSL 'https://julialang-s3.julialang.org/bin/linux/x64/1.5/julia-1.5.0-beta1-linux-x86_64.tar.gz' -o julia.tar.gz

# %% [markdown]
# # インストール

# %%
!tar -xzf julia.tar.gz -C /usr --strip-components 1
!rm -rf julia.tar.gz*
!julia -e 'using Pkg; pkg"add IJulia"'
# Out:
#     Cloning default registries into `~/.julia`
#     Cloning registry from "https://github.com/JuliaRegistries/General.git"
#       Added registry `General` to `~/.julia/registries/General`
#   Resolving package versions...
#   Installed MbedTLS_jll ───── v2.16.0+2
#   Installed VersionParsing ── v1.2.0
#   Installed SoftGlobalScope ─ v1.0.10
#   Installed ZeroMQ_jll ────── v4.3.2+3
#   Installed Parsers ───────── v1.0.4
#   Installed IJulia ────────── v1.21.2
#   Installed Conda ─────────── v1.4.1
#   Installed JSON ──────────── v0.21.0
#   Installed MbedTLS ───────── v1.0.2
#   Installed ZMQ ───────────── v1.2.0
# ...
# ######################################################################## 100.0%
# ...
# ######################################################################## 100.0%
#    Updating `~/.julia/environments/v1.4/Project.toml`
#   [7073ff75] + IJulia v1.21.2
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#   [8f4d0f93] + Conda v1.4.1
#   [7073ff75] + IJulia v1.21.2
# ...

# %% [markdown]
# # パッケージ追加例
# ※パッケージを追加する際は「ランタイムのタイプを変更」前に実行する

# %%
!julia -e 'using Pkg; pkg" add Flux;"'
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#   Resolving package versions...
#   Installed OpenSpecFun_jll ────────────── v0.5.3+3
#   Installed DataAPI ────────────────────── v1.3.0
#   Installed Adapt ──────────────────────── v1.1.0
#   Installed DiffResults ────────────────── v1.0.2
#   Installed CUDAapi ────────────────────── v4.0.0
#   Installed Juno ───────────────────────── v0.8.2
#   Installed StatsBase ──────────────────── v0.33.0
#   Installed Flux ───────────────────────── v0.10.4
#   Installed CodecZlib ──────────────────── v0.7.0
#   Installed SortingAlgorithms ──────────── v0.3.1
#   Installed ForwardDiff ────────────────── v0.10.10
#   Installed GPUCompiler ────────────────── v0.2.0
#   Installed BinaryProvider ─────────────── v0.5.10
#   Installed DataStructures ─────────────── v0.17.17
#   Installed Zygote ─────────────────────── v0.4.20
# ...

# %% [markdown]
# 上記を実行後、「ランタイム」->「ランタイムのタイプを変更」->「保存」を行う。

# %% [markdown]
# # version確認

# %%
versioninfo()
# Out:
# Julia Version 1.4.2
# Commit 44fa15b150* (2020-05-23 18:35 UTC)
# Platform Info:
#   OS: Linux (x86_64-pc-linux-gnu)
#   CPU: Intel(R) Xeon(R) CPU @ 2.30GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-8.0.1 (ORCJIT, haswell)

# %% [markdown]
# # コード

# %%
# ToDo
